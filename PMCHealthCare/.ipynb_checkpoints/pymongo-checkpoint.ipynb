# %%
# Python code to illustrate 
# inserting data in MongoDB 
from pymongo import MongoClient 
  
try: 
    conn = MongoClient() 
    print("Connected successfully!!!") 
except:   
    print("Could not connect to MongoDB") 
  
# database 
db = conn.Record 
  
# Created or Switched to collection names: my_gfg_collection 
collection = db.patient
# Out:
# Connected successfully!!!

# %%
    s = "PMCP" + str(1)
    result = collection.update_many( 
        {"aadhar_no":123456789012}, 
        { 
                "$set":{ 
                        "patient_id":s
                        },
                  
        } 
        ) 
    print(result)

# %%
for i in range(1,7):
    s = "PMCD" + str(i)
    result = collection.update_many( 
        {"registration_no":i}, 
        { 
                "$set":{ 
                        "doctor_id":s
                        },
                  
        } 
        ) 
    #print(s)

# %%
cursor = collection.find()
for record in cursor: 
    print(record["aadhar_no"])
# Out:
# 123456789012
# 998765432109
# 567890123456
# 112233445566

# %%
collection = db.doctor
cursor = collection.find()
for record in cursor: 
    print(record)
# Out:
# {'name': 'Dr. Jadhav Nilesh Balajia', 'qualtification': 'MBBS', 'doctor_id': 'PMCD1', 'phone_no': 9988776655, 'registration_no': 1, 'email_id': 'abc@gmail.com', '_id': ObjectId('5b97c20658a698b30de181fa')}
# {'name': 'Dr. Doshi Sandesh Jawaharlal', 'qualtification': 'MBBS', 'doctor_id': 'PMCD2', 'phone_no': 9988776655, 'registration_no': 2, 'email_id': 'abc@gmail.com', '_id': ObjectId('5b97c20658a698b30de181fb')}
# {'name': 'Dr. Shaikh Iqbal Babulal', 'qualtification': 'MBBS', 'doctor_id': 'PMCD3', 'phone_no': 9988776655, 'registration_no': 3, 'email_id': 'abc@gmail.com', '_id': ObjectId('5b97c20658a698b30de181fc')}
# {'name': 'Dr. Birajdar Rahul Suryakantrao', 'qualtification': 'MBBS', 'doctor_id': 'PMCD4', 'phone_no': 9988776655, 'registration_no': 4, 'email_id': 'abc@gmail.com', '_id': ObjectId('5b97c20658a698b30de181fd')}
# ...

# %%
collection = db.doctor

# %%
cursor = collection.find()
for record in cursor: 
    print(record)

# %%
for i in range(1,3):
    s = "PMCM" + str(i)
    result = collection.update_many( 
        {"registration_no":i}, 
        { 
                "$set":{ 
                        "pharmacist_id":s
                        },
                  
        } 
        )

# %%
cursor = collection.find()
for record in cursor: 
    print(record)
# Out:
# {'pharmacist_id': 'PMCM1', 'name': 'Ramesh pawar', 'address': 'Pune', 'phone_no': 1234554321, 'registration_no': 1, 'email_id': 'abc@gmail.com', '_id': ObjectId('5b97c64358a698b30de18204')}
# {'pharmacist_id': 'PMCM2', 'name': 'suresh pawar', 'address': 'pune', 'phone_no': 6789012345, 'registration_no': 2, 'email_id': 'xyz@gmail.com', '_id': ObjectId('5b97c64358a698b30de18205')}

# %%
collection = db.hospital

# %%
cursor = collection.find()
for record in cursor: 
    print(record)
# Out:
# {'Facilities': 0, 'District_ID': 521, 'pincode': 410301, 'Website': 0, 'Specialties': 0, 'Total_Num_Beds': 0, '_id': ObjectId('5b97be2c58a698b30de17f66'), 'Location_Coordinates': '18.7692034, 73.3767641', 'Number_DoctorVillage': '', 'Subtown': 0, 'address': 'Lonan Tal. Khandala', 'Town': 0, 'email': 0, 'name': 'Ashwini Hospital', 'phone_no': 0, 'registration_no': 18314, 'hospital_type': 0, 'State_ID': 27}
# {'Facilities': 0, 'District_ID': 521, 'pincode': 410401, 'Website': 0, 'Specialties': 0, 'Total_Num_Beds': 0, '_id': ObjectId('5b97be2c58a698b30de17f67'), 'Location_Coordinates': '18.7546171, 73.4062342', 'Number_DoctorVillage': '', 'Subtown': 0, 'address': 'Akshay Medical Foundation Parmar Hospital G 204, Main Road Lonavla G 204, Main Road Lonavla', 'Town': 0, 'email': 0, 'name': 'Akshay Medical Foundation, Lonavla', 'phone_no': 0, 'registration_no': 18315, 'hospital_type': 0, 'State_ID': 27}
# ...

# %%
#18314
#18973
j = 1
for i in range(18314,18974):
   
    s = "PMCH" + str(j)
    result = collection.update_many( 
        {"registration_no":i}, 
        { 
                "$set":{ 
                        "hospital_id":s
                        },
                  
        } 
        )
    j+=1

# %%
cursor = collection.find()
for record in cursor: 
    print(record)
# Out:
# {'Facilities': 0, 'District_ID': 521, 'pincode': 410301, 'Website': 0, 'Specialties': 0, 'Total_Num_Beds': 0, 'hospital_id': 'PMCH1', '_id': ObjectId('5b97be2c58a698b30de17f66'), 'Location_Coordinates': '18.7692034, 73.3767641', 'Number_DoctorVillage': '', 'Subtown': 0, 'address': 'Lonan Tal. Khandala', 'Town': 0, 'email': 0, 'name': 'Ashwini Hospital', 'phone_no': 0, 'registration_no': 18314, 'hospital_type': 0, 'State_ID': 27}
# {'Facilities': 0, 'District_ID': 521, 'pincode': 410401, 'Website': 0, 'Specialties': 0, 'Total_Num_Beds': 0, 'hospital_id': 'PMCH2', '_id': ObjectId('5b97be2c58a698b30de17f67'), 'Location_Coordinates': '18.7546171, 73.4062342', 'Number_DoctorVillage': '', 'Subtown': 0, 'address': 'Akshay Medical Foundation Parmar Hospital G 204, Main Road Lonavla G 204, Main Road Lonavla', 'Town': 0, 'email': 0, 'name': 'Akshay Medical Foundation, Lonavla', 'phone_no': 0, 'registration_no': 18315, 'hospital_type': 0, 'State_ID': 27}
# ...

# %%
s1 = "PMCH1"
s2 = "PMCD2"
print(s1[3])
print(s2[3])
# Out:
# H
# D

# %%
collection.count()
# Out:
# /home/shraddha/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   if __name__ == '__main__':
# 660

# %%
# User document creation
# inserting data in MongoDB 
from pymongo import MongoClient 
  
try: 
    conn = MongoClient() 
    print("Connected successfully!!!") 
except:   
    print("Could not connect to MongoDB") 
  
# database 
db = conn.database 
  
# Created or Switched to collection names: my_gfg_collection 
collection = db.user 
#c2 = db.pharmacist
#n = c2.count()
#print(n)
#n+=1
for i in range(18314,18974):
    rec1 = { 
            "user_id":i, 
            "password":12345, 
            "u_type":"H"
            } 
    rec_id1 = collection.insert_one(rec1) 
# Insert Data 

  
# Printing the data inserted 
cursor = collection.find() 
for record in cursor: 
    print(record)
# Out:
# Connected successfully!!!
# {'user_id': 1, 'u_type': 'M', '_id': ObjectId('5b9a66b7b1463b2f2bee6941'), 'password': 12345}
# {'user_id': 2, 'u_type': 'M', '_id': ObjectId('5b9a66b8b1463b2f2bee6942'), 'password': 12345}
# {'user_id': 1, 'u_type': 'P', '_id': ObjectId('5b9a66eeb1463b2f2bee6944'), 'password': 12345}
# {'user_id': 2, 'u_type': 'P', '_id': ObjectId('5b9a66eeb1463b2f2bee6945'), 'password': 12345}
# {'user_id': 3, 'u_type': 'P', '_id': ObjectId('5b9a66eeb1463b2f2bee6946'), 'password': 12345}
# {'user_id': 4, 'u_type': 'P', '_id': ObjectId('5b9a66eeb1463b2f2bee6947'), 'password': 12345}
# {'user_id': 1, 'u_type': 'D', '_id': ObjectId('5b9a676ab1463b2f2bee694a'), 'password': 12345}
# {'user_id': 2, 'u_type': 'D', '_id': ObjectId('5b9a676ab1463b2f2bee694b'), 'password': 12345}
# {'user_id': 3, 'u_type': 'D', '_id': ObjectId('5b9a676ab1463b2f2bee694c'), 'password': 12345}
# {'user_id': 4, 'u_type': 'D', '_id': ObjectId('5b9a676ab1463b2f2bee694d'), 'password': 12345}
# ...

# %%
cursor = collection.find() 
for record in cursor: 
    print(record)

# %%
from pymongo import MongoClient 
  
try: 
    conn = MongoClient() 
    print("Connected successfully!!!") 
except:   
    print("Could not connect to MongoDB") 
  
# database 
db = conn.Record 
  
# Collections
cp = db.patient 
cd = db.doctor 
cm = db.pharmacist 
ch = db.hospital
# Out:
# Connected successfully!!!

# %%
c=cp.count()+1
s= "PMCH"+str(c)
# Out:
# /home/shraddha/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   if __name__ == '__main__':

# %%
print(s)
# Out:
# PMCH5

# %%
from pymongo import MongoClient 
  
try: 
    conn = MongoClient() 
    print("Connected successfully!!!") 
except:   
    print("Could not connect to MongoDB") 
  
# database 
db = conn.Record 

collection = db.hospital
c =collection.find_one({"hospital_id": "PMCH1"})
print(c["password"])
if
# Out:
# Connected successfully!!!
# 12345

# %%
# Python code to illustrate 
# inserting data in MongoDB 
from pymongo import MongoClient 
  
try: 
    conn = MongoClient() 
    print("Connected successfully!!!") 
except:   
    print("Could not connect to MongoDB") 
  
# database 
db = conn.Record 
  
# Created or Switched to collection names: my_gfg_collection 
collection = db.doctor 


result = collection.update_many( 
        {"password":"12345"}, 
        { 
                "$rename":{ 
                        "email_id":"email"
                        }
                } 
        ) 

  
cursor = collection.find() 
for record in cursor: 
    print(record)
# Out:
# Connected successfully!!!
# {'doctor_id': 'PMCD1', 'email': 'abc@gmail.com', '_id': ObjectId('5b97c20658a698b30de181fa'), 'password': '12345', 'qualification': 'MBBS', 'phone1': 9988776655, 'registration_no': 1, 'name': 'Dr. Jadhav Nilesh Balajia'}
# {'doctor_id': 'PMCD2', 'email': 'abc@gmail.com', '_id': ObjectId('5b97c20658a698b30de181fb'), 'password': '12345', 'qualification': 'MBBS', 'phone1': 9988776655, 'registration_no': 2, 'name': 'Dr. Doshi Sandesh Jawaharlal'}
# {'doctor_id': 'PMCD3', 'email': 'abc@gmail.com', '_id': ObjectId('5b97c20658a698b30de181fc'), 'password': '12345', 'qualification': 'MBBS', 'phone1': 9988776655, 'registration_no': 3, 'name': 'Dr. Shaikh Iqbal Babulal'}
# {'doctor_id': 'PMCD4', 'email': 'abc@gmail.com', '_id': ObjectId('5b97c20658a698b30de181fd'), 'password': '12345', 'qualification': 'MBBS', 'phone1': 9988776655, 'registration_no': 4, 'name': 'Dr. Birajdar Rahul Suryakantrao'}
# ...

# %%
result = collection.update_many( 
        {"password":"12345"}, 
        { 
                "$set":{ 
                        'dob': '1998-09-19'
                        }
                } 
        ) 

  
cursor = collection.find() 
for record in cursor: 
    print(record)
# Out:
# {'local_addr': 'pune', 'blood_grp': 'B+ve', '_id': ObjectId('5b97c47b58a698b30de18200'), 'password': '12345', 'spouse_name': '', 'phone1': 9988776655, 'dob': '1998-09-19', 'profession': 'student', 'gender': 'female', 'marital_status': 'unmarried', 'aadhar_no': 123456789012, 'patient_id': 'PMCP1', 'email_id': 'abc@gmail.com', 'name': 'Tanvi Bhargaw', 'permanent_addr': 'pune'}
# {'local_addr': 'pune', 'blood_grp': 'A+ve', '_id': ObjectId('5b97c47b58a698b30de18201'), 'password': '12345', 'spouse_name': '', 'phone1': 9988776655, 'dob': '1998-09-19', 'profession': 'teacher', 'gender': 'female', 'marital_status': 'unmarried', 'aadhar_no': 998765432109, 'patient_id': 'PMCP2', 'email_id': 'abc@gmail.com', 'name': 'Rutuja Taware', 'permanent_addr': 'pune'}
# ...

# %%
# Python code to illustrate 
# inserting data in MongoDB 
from pymongo import MongoClient 
  
try: 
    conn = MongoClient() 
    print("Connected successfully!!!") 
except:   
    print("Could not connect to MongoDB") 
  
# database 
db = conn.Record 
  
# Created or Switched to collection names: my_gfg_collection 
collection = db.hospital

#r = collection.remove({"registration_no":"shraddha"})
print(r)
cursor = collection.find() 
for record in cursor: 
    print(record)
# Out:
# Connected successfully!!!
# {'ok': 1, 'n': 1}
# {'hospital_id': 'PMCH1', 'Total_Num_Beds': 0, 'Number_DoctorVillage': '', '_id': ObjectId('5b97be2c58a698b30de17f66'), 'password': '12345', 'Location_Coordinates': '18.7692034, 73.3767641', 'address': 'Lonan Tal. Khandala', 'registration_no': 18314, 'name': 'Ashwini Hospital', 'District_ID': 521, 'pincode': 410301, 'phone_no': 0, 'Facilities': 0, 'Town': 0, 'Website': 0, 'email': 0, 'Specialties': 0, 'Subtown': 0, 'hospital_type': 0, 'State_ID': 27}
# ...

# %%
collection.remove({"hopsital_id":"PMCH661"})
# Out:
# /home/shraddha/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: DeprecationWarning: remove is deprecated. Use delete_one or delete_many instead.
#   if __name__ == '__main__':
# {'n': 0, 'ok': 1}

# %%
db.hospital.delete({"hopsital_id":"PMCH661"})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-f422989ac4d5> in <module>()
# ----> 1 db.hospital.delete({"hopsital_id":"PMCH661"})
#
# /home/shraddha/anaconda3/lib/python3.5/site-packages/pymongo/collection.py in __call__(self, *args, **kwargs)
#    3319                         "call the '%s' method on a 'Collection' object it is "
#    3320                         "failing because no such method exists." %
# -> 3321                         self.__name.split(".")[-1])
#
# TypeError: 'Collection' object is not callable. If you meant to call the 'delete' method on a 'Collection' object it is failing because no such method exists.

# %%
# Python code to illustrate 
# inserting data in MongoDB 
#prescription
from pymongo import MongoClient 
  
try: 
    conn = MongoClient() 
    print("Connected successfully!!!") 
except:   
    print("Could not connect to MongoDB") 
  
# database 
db = conn.Record 
"""
# Created or Switched to collection names: my_gfg_collection 
collection = db.prescription

rec1 = { 
            "medicine_name":"imol", 
            "morning":1, 
            "afternoon":1,
            "evening" : 1,
            "no_of_days" : 3
            } 

rec3 = { 
            "medicine_name":"aciloc", 
            "morning":1, 
            "afternoon":1,
            "evening" : 1,
            "no_of_days" : 3
            } 

rec2 = {
    "prescription_id":"PMCP1PR2",
    "medicine" :[ rec1,rec3]
}
rec_id1 = collection.insert_one(rec2) 

#collection.delete_many({"prescription_id":"PMCP1PR2"})

cursor = collection.find() 
for record in cursor: 
    for m in record["medicine"]:
        print(m["medicine_name"]) 
    break;
# Out:
# Connected successfully!!!
# imol
# aciloc

# %%
cursor = collection.find() 
for record in cursor:
    print(record)
# Out:
# {'prescription_id': 'PMCP1PR1', 'medicine': [{'afternoon': 1, 'morning': 1, 'evening': 1, 'medicine_name': 'imol', 'no_of_days': 3}, {'afternoon': 1, 'morning': 1, 'evening': 1, 'medicine_name': 'aciloc', 'no_of_days': 3}], '_id': ObjectId('5b9cb837b1463b0d63e2ff54')}
# {'prescription_id': 'PMCP1PR2', 'medicine': [{'afternoon': 1, 'morning': 1, 'evening': 1, 'medicine_name': 'imol', 'no_of_days': 3}, {'afternoon': 1, 'morning': 1, 'evening': 1, 'medicine_name': 'aciloc', 'no_of_days': 3}], '_id': ObjectId('5b9cbb51b1463b0d63e2ff61')}

# %%
collection = db.prescription
cursor = collection.find()
i=0
for record in cursor: 
    for m in record["medicine"]:
        i+=1
        print(m["medicine_name"]) 
    print(i)
    break;
# Out:
# imol
# aciloc
# 2

# %%
collection = db.prescription

c1 = collection.find_one({"prescription_id":"PMCP1PR1"})
#print(c1)
c2 = collection.find_one({"prescription_id":"PMCP1PR2"})
#print(c2)
c3 = [c1,c2]
collection2 = db.patient

result = collection2.update_many( 
        {"patient_id":"PMCP1"}, 
        { 
                "$set":{ 
                        "prescription":c3
                        }
                } 
        ) 

#rec_id1 = collection2.insert_one(result)

cursor = collection2.find() 
for record in cursor: 
    print(record)
# Out:
# {'prescription_id': 'PMCP1PR1', 'medicine': [{'afternoon': 1, 'morning': 1, 'evening': 1, 'medicine_name': 'imol', 'no_of_days': 3}, {'afternoon': 1, 'morning': 1, 'evening': 1, 'medicine_name': 'aciloc', 'no_of_days': 3}], '_id': ObjectId('5b9cb837b1463b0d63e2ff54')}
# {'prescription_id': 'PMCP1PR2', 'medicine': [{'afternoon': 1, 'morning': 1, 'evening': 1, 'medicine_name': 'imol', 'no_of_days': 3}, {'afternoon': 1, 'morning': 1, 'evening': 1, 'medicine_name': 'aciloc', 'no_of_days': 3}], '_id': ObjectId('5b9cbb51b1463b0d63e2ff61')}
# ...

# %%
collection = db.patient
cursor = collection.find()
i=0
c =[]
for record in cursor: 
    for m in record["prescription"]:
        i+=1
        c.append(m)

   
    break;
print(c) 
print(i)
# Out:
# [{'_id': ObjectId('5b9cb837b1463b0d63e2ff54'), 'prescription_id': 'PMCP1PR1', 'medicine': [{'evening': 1, 'medicine_name': 'imol', 'morning': 1, 'afternoon': 1, 'no_of_days': 3}, {'evening': 1, 'medicine_name': 'aciloc', 'morning': 1, 'afternoon': 1, 'no_of_days': 3}]}, {'_id': ObjectId('5b9cbb51b1463b0d63e2ff61'), 'prescription_id': 'PMCP1PR2', 'medicine': [{'evening': 1, 'medicine_name': 'imol', 'morning': 1, 'afternoon': 1, 'no_of_days': 3}, {'evening': 1, 'medicine_name': 'aciloc', 'morning': 1, 'afternoon': 1, 'no_of_days': 3}]}]
# 2

# %%
# Python code to illustrate 
# inserting data in MongoDB 
#prescription
from pymongo import MongoClient 
  
try: 
    conn = MongoClient() 
    print("Connected successfully!!!") 
except:   
    print("Could not connect to MongoDB") 
  
# database 
db = conn.Record 
c = db.patient

"""
result = c.update_many( 
        {"marital_status":"unmarried"}, 
        { 
                "$set":{ 
                        "prescription":""
                        }
                } 
        ) 
"""
cursor = c.find() 
for record in cursor: 
    print(record)
# Out:
# Connected successfully!!!
# {'marital_status': 'unmarried', 'patient_id': 'PMCP1', 'phone1': 9988776655, 'blood_grp': 'B+ve', 'email_id': 'abc@gmail.com', 'local_addr': 'pune', 'name': 'Tanvi Bhargaw', 'password': '12345', 'spouse_name': '', 'permanent_addr': 'pune', 'gender': 'female', 'dob': '1998-09-19', 'profession': 'student', 'aadhar_no': 123456789012, '_id': ObjectId('5b97c47b58a698b30de18200'), 'prescription': [{'medicine': [{'no_of_days': '2', 'afternoon': '1', 'medicine_name': 'imol', 'evening': '1', 'morning': '1'}, {'no_of_days': '3', 'afternoon': '1', 'medicine_name': 'aciloc', 'evening': '1', 'morning': '1'}], '_id': ObjectId('5baa6cf7b1463b27557dd8a1'), 'prescription_id': 'PMCP1PR0'}, {'medicine': [{'medicine_name': 'crocin', 'afternoon': '1', 'no_of_days': '6', 'evening': '1', 'morning': '1'}], '_id': ObjectId('5baa6d48b1463b27557dd8a2'), 'prescription_id': 'PMCP1PR1'}]}
# ...

# %%
cursor = collection.find({"patient_id":"PMCP1"})
no=0
#res2 is a list of prescription
res2 = []

c = collection.find({"patient_id":"PMCP1"},{"prescription": {"$exists": False}})
print(c.count())
print(c.size())
# Out:
# 1
# /home/shraddha/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-ca3901c49238> in <module>()
#       6 c = collection.find({"patient_id":"PMCP1"},{"prescription": {"$exists": False}})
#       7 print(c.count())
# ----> 8 print(c.size())
#
# AttributeError: 'Cursor' object has no attribute 'size'
