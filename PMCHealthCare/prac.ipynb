# %%
from mongoengine import *

# %%
class Doctor(Document):
    doctor_id = StringField(max_length = 20)

# %%
class Hospital(Document):
    hospital_id = StringField(max_length = 20)
    doctors_associated = ListField(ReferenceField(Doctor))

# %%
connect()
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True, read_preference=Primary())

# %%
d1 = Doctor(doctor_id = 'a')
d1.save()
# Out:
# <Doctor: Doctor object>

# %%
d2 = Doctor(doctor_id = 'b')
d2.save()
# Out:
# <Doctor: Doctor object>

# %%
h1 = Hospital( hospital_id = '1' , doctors_associated = [d1 , d2] )

# %%
h1.save()
# Out:
# <Hospital: Hospital object>

# %%
for h in Hospital.objects.all():
    print(h['doctors_associated'])
# Out:
# [<Doctor: Doctor object>, <Doctor: Doctor object>]

# %%
o1 , o2 = h['doctors_associated']

# %%
o1['doctor_id']
# Out:
# 'a'

# %%
h2 = Hospital( hospital_id = '2' , doctors_associated = [d1['doctor_id'] , d2['doctor_id']] )

# %%
h2.save()
# Out:
# <Hospital: Hospital object>

# %%
i ,j = h2['doctors_associated']

# %%
i
# Out:
# DBRef('doctor', 'a')

# %%
j
# Out:
# DBRef('doctor', 'b')

# %%
h4 = Hospital( hospital_id = '3' , doctors_associated = ['c', 'd' ])

# %%
h4.save()
# Out:
# <Hospital: Hospital object>

# %%
i ,j = h4['doctors_associated']

# %%
i
# Out:
# DBRef('doctor', 'c')

# %%
j
# Out:
# DBRef('doctor', 'd')

# %%
i = 'a'
for m in Doctor.objects.all():
    if m['doctor_id'] == i:
        print(m['doctor_id'])
# Out:
# a
# a

# %%
h5 = Hospital( hospital_id = '4' , doctors_associated = [1,2 ])

# %%
h5.save()
# Out:
# <Hospital: Hospital object>

# %%
class Comment(EmbeddedDocument):
    content = StringField(max_length = 20)

# %%
class Post(Document):
    comments = ListField(EmbeddedDocumentField(Comment))

# %%
c1 = Comment(content = '1')

# %%
c1.save()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-3f04780920d1> in <module>()
# ----> 1 c1.save()
#
# /home/shraddha/anaconda3/lib/python3.5/site-packages/mongoengine/document.py in save(self, *args, **kwargs)
#      90
#      91     def save(self, *args, **kwargs):
# ---> 92         self._instance.save(*args, **kwargs)
#      93
#      94     def reload(self, *args, **kwargs):
#
# AttributeError: 'NoneType' object has no attribute 'save'

# %%
comments1 = [Comment(content = '1') , Comment(content = '2') ]
p1 = Post( comments = comments1  )
p1.save()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-3cd14bf18679> in <module>()
#       1 comments1 = [Comment(content = '1') , Comment(content = '2') ]
# ----> 2 p1 = Post( comments = comments1  )
#       3 p1.save()
#
# /home/shraddha/anaconda3/lib/python3.5/site-packages/mongoengine/base/document.py in __init__(self, *args, **values)
#     114                         field = self._fields.get(key)
#     115                         if field and not isinstance(field, FileField):
# --> 116                             value = field.to_python(value)
#     117                     setattr(self, key, value)
#     118                 else:
#
# /home/shraddha/anaconda3/lib/python3.5/site-packages/mongoengine/base/fields.py in to_python(self, value)
#     326             self.field._auto_dereference = self._auto_dereference
#     327             value_dict = {key: self.field.to_python(item)
# --> 328                           for key, item in list(value.items())}
#     329         else:
#     330             Document = _import_class('Document')
#
# /home/shraddha/anaconda3/lib/python3.5/site-packages/mongoengine/base/fields.py in <dictcomp>(.0)
#     326             self.field._auto_dereference = self._auto_dereference
#     327             value_dict = {key: self.field.to_python(item)
# --> 328                           for key, item in list(value.items())}
#     329         else:
#     330             Document = _import_class('Document')
#
# /home/shraddha/anaconda3/lib/python3.5/site-packages/mongoengine/fields.py in to_python(self, value)
#     638     def to_python(self, value):
#     639         if not isinstance(value, self.document_type):
# --> 640             return self.document_type._from_son(value, _auto_dereference=self._auto_dereference)
#     641         return value
#     642
#
# /home/shraddha/anaconda3/lib/python3.5/site-packages/mongoengine/base/document.py in _from_son(cls, son, _auto_dereference, only_fields, created)
#     673
#     674         if son and not isinstance(son, dict):
# --> 675             raise ValueError("The source SON object needs to be of type 'dict'")
#     676
#     677         # Get the class name from the document, falling back to the given
#
# ValueError: The source SON object needs to be of type 'dict'
